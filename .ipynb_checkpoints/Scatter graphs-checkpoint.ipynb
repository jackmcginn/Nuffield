# %%
# %pylab inline
import csv
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
dataPath_1 = 'C:/Users/nuffield/Desktop/Nuffield-master/XPS_data_raw_updated.csv'
p = open(dataPath_1)
# Out:
# <_io.TextIOWrapper name='C:/Users/nuffield/Desktop/Nuffield-master/XPS_data_raw_updated.csv' mode='r' encoding='cp1252'>

# %%
dataPath = 'TCO_data.json'

with open(dataPath) as f:
    data = json.load(f)

# %%
ratio = []
ne = []
comp = {}
n = 1
mob = []
Rs = []

# %%
reader = csv.reader(p)
for row in reader:
    if n == 1:
        n += 1
    else:
        x = str(float(row[0]))
        y = str(float(row[1]))
        comp[x + ' ' + y] = float(row[2])/float(row[5])

# %%
for item in comp:
    ne.append(data.get(item).get('ne'))
    ratio.append(comp.get(item))
    mob.append(data.get(item).get('mob'))
    Rs.append(log(data.get(item).get('Rs')))

# %%
plt.plot(ratio, ne, 'o')
plt.ylabel('Carrier concentration', fontsize = 14)
plt.xlabel('Aluminium Zinc composition', fontsize = 14)
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10)
plt.show()

# %%
plt.plot(ratio, mob, 'o', color='red')
plt.ylabel('Electron mobility (cm^2/V·s)', fontsize = 14)
plt.xlabel('Aluminium Zinc composition', fontsize = 14)
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10)
plt.show()

# %%
plt.plot(ratio,  Rs, 'o', color = 'green')
plt.ylabel('Log of Resisitvity (Ωcm)', fontsize = 14)
plt.xlabel('Aluminium Zinc composition', fontsize = 14)
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10)
plt.show()

# %%
plt.plot(ne,  mob, 'o', color = 'purple')
plt.ylabel('Electron mobility (cm^2/V·s)', fontsize = 14)
plt.xlabel('Carrier concentration', fontsize = 14)
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10)
plt.show()
