# %%
# %pylab inline
import numpy as np
import csv
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
dataPath = 'C:/Users/tijil/Downloads/Nuffield-master/Nuffield-master/XPS_data_raw_updated.csv'
p = open(dataPath)

# %%
dataPath = 'C:/Users/tijil/Downloads/datalogging/TCO_data.json'

with open(dataPath) as f:
    data = json.load(f)

# %%
Al = []
Zn = []
position = []
ratio = []
ne = []
ordered_ratio = []
graph = {}
comp = {}
n = 1
m = 0
mob = []
Rs = []

# %%
reader = csv.reader(p)
for row in reader:
    if n == 1:
        n += 1
    else:
        Al.append(float(row[2]))
        Zn.append(float(row[5]))
        x = str(float(row[0]))
        y = str(float(row[1]))
        position.append(x + ' ' + y)
        comp[x + ' ' + y] = float(row[2])/float(row[5])

# %%
for item in data:
    ne.append(data.get(item).get('ne'))
    ratio.append(comp.get(item))
    mob.append(data.get(item).get('mob'))
    Rs.append(log(data.get(item).get('Rs')))

# %%
plt.plot(ratio,ne, 'o')
plt.xlabel('Aluminum zinc composition', fontsize=20)
plt.ylabel('Carrier concentration', fontsize=20)
matplotlib.rc('xtick', labelsize= 14)
matplotlib.rc('ytick', labelsize= 14)
plt.show()

# %%
plt.plot(ratio,mob, 'o', color = 'red')
plt.xlabel('Aluminum zinc composition', fontsize=20)
plt.ylabel('Electron mobility(cm^2/V·s)', fontsize=20)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)
plt.show()

# %%
plt.plot(ratio,Rs, 'o', color = 'green')
plt.xlabel('Aluminum zinc composition', fontsize=20)
plt.ylabel('Resisitivity(Ω·cm)', fontsize=20)
matplotlib.rc('xtick', labelsize= 14)
matplotlib.rc('ytick', labelsize= 14)
plt.show()
